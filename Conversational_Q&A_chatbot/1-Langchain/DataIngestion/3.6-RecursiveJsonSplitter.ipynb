# %% [markdown]
# ### HOw to split json file ?

# %%
import json
import requests 
json_data = requests.get("https://api.smith.langchain.com/openapi.json").json()

json_data

# %%
print("hdkfhs")
# Out:
# hdkfhs
